# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
curr_path = '/content/drive/MyDrive/BERT_Pipeline/' #change the path
os.chdir(curr_path)

# %%
# !pip install transformers[torch]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 2.9 MB/s eta 0:00:00
# ...

# %%
import BERT_Pipeline

report_path = "SourceData"
BERT_Pipeline.generate(report_path)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/839 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# File 'SourceData/TCS/Summary/TCS_CEO_summary.txt' already exists. It will be overwritten.
# File 'SourceData/TCS/Summary/TCS_MDA_summary.txt' already exists. It will be overwritten.
# File 'SourceData/TCSS/Summary/TCS_MDA_summary.txt' already exists. It will be overwritten.
# File 'SourceData/TCSS/Summary/TCS_CEO_summary.txt' already exists. It will be overwritten.
#     <div>
#
#       <progress value='35' max='36' style='width:300px; height:20px; vertical-align: middle;'></progress>
# ...
